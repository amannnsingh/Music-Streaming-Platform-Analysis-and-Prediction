# %% [markdown]
# # MUSIC STREAMING PLATFORM ANALYSIS

# %% [markdown]
# # Importing Datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading Data Set 
tracks = pd.read_csv('tracks.csv')
genre = pd.read_csv('artists.csv')
df = pd.read_csv('tracks.csv', delimiter=',', encoding="utf-8-sig")

# %%
tracks.head()
# Out:
#                        id                                  name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                 Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  ...  mode  speechiness  acousticness  \
# 0   22/02/1922         0.645  0.4450  ...     1       0.4510         0.674
# 1   01/06/1922         0.695  0.2630  ...     1       0.9570         0.797
# 2   21/03/1922         0.434  0.1770  ...     1       0.0512         0.994
# 3   21/03/1922         0.321  0.0946  ...     1       0.0504         0.995
# 4         1922         0.402  0.1580  ...     0       0.0390         0.989
#
#    instrumentalness  liveness  valence    tempo  time_signature  Unnamed: 20  \
# 0            0.7440     0.151    0.127  104.851               3          NaN
# 1            0.0000     0.148    0.655  102.009               1          NaN
# 2            0.0218     0.212    0.457  130.418               5          NaN
# 3            0.9180     0.104    0.397  169.980               3          NaN
# 4            0.1300     0.311    0.196  103.220               4          NaN
#
#    release_date.1
# 0          2018.0
# 1          2001.0
# 2          2002.0
# 3          2003.0
# 4          2001.0
#
# [5 rows x 22 columns]

# %%
genre.head()
# Out:
#                        id  followers genres  \
# 0  0DheY5irMjBUeLybbCUEZ2        0.0     []
# 1  0DlhY15l3wsrnlfGio2bjU        5.0     []
# 2  0DmRESX2JknGPQyO15yxg7        0.0     []
# 3  0DmhnbHjm1qw6NCYPeZNgJ        0.0     []
# 4  0Dn11fWM7vHQ3rinvWEl4E        2.0     []
#
#                                              name  popularity
# 0  Armid & Amir Zare Pashai feat. Sara Rouzbehani           0
# 1                                     ปูนา ภาวิณี           0
# 2                                           Sadaa           0
# 3                                       Tra'gruda           0
# 4                          Ioannis Panoutsopoulos           0

# %% [markdown]
# # Music Tracks Dataset Analysis

# %%
# checking null values
pd.isnull(tracks).sum()
# Out:
# id                       0
# name                    71
# popularity               0
# duration_ms              0
# explicit                 0
# artists                  0
# id_artists               0
# release_date             0
# danceability             0
# energy                   0
# key                      0
# loudness                 0
# mode                     0
# speechiness              0
# acousticness             0
# instrumentalness         0
# liveness                 0
# valence                  0
# tempo                    0
# time_signature           0
# Unnamed: 20         586672
# release_date.1      586659
# dtype: int64

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
#  20  Unnamed: 20       0 non-null       float64
#  21  release_date.1    13 non-null      float64
# dtypes: float64(11), int64(6), object(5)
# memory usage: 98.5+ MB

# %% [markdown]
# # Descriptive statistics of Music tracks

# %%
tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# liveness          586672.0       0.213935       0.184326     0.0       0.0983
# valence           586672.0       0.552292       0.257671     0.0       0.3460
# tempo             586672.0     118.464857      29.764108     0.0      95.6000
# time_signature    586672.0       3.873382       0.473162     0.0       4.0000
# Unnamed: 20            0.0            NaN            NaN     NaN          NaN
# release_date.1        13.0    2004.384615       4.407162  2001.0    2002.0000
#
#                             50%           75%          max
# popularity            27.000000      41.00000      100.000
# duration_ms       214893.000000  263867.00000  5621218.000
# explicit               0.000000       0.00000        1.000
# danceability           0.577000       0.68600        0.991
# energy                 0.549000       0.74800        1.000
# key                    5.000000       8.00000       11.000
# loudness              -9.243000      -6.48200        5.376
# mode                   1.000000       1.00000        1.000
# speechiness            0.044300       0.07630        0.971
# acousticness           0.422000       0.78500        0.996
# instrumentalness       0.000024       0.00955        1.000
# liveness               0.139000       0.27800        1.000
# valence                0.564000       0.76900        1.000
# tempo                117.384000     136.32100      246.381
# time_signature         4.000000       4.00000        5.000
# Unnamed: 20                 NaN           NaN          NaN
# release_date.1      2004.000000    2005.00000     2018.000

# %% [markdown]
# # Top 10 most popular songs on platform

# %%
most = tracks.query('popularity > 90', inplace = False).sort_values('popularity', ascending = False)
most[:10]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                              telepatÃ­a
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 91866  60ynsPSSKe6O3sfwRnIBRf                                 Streets
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# 92810          97       215627         1
# 92811          97       160191         0
# 92813          96       200040         0
# 93805          96       242096         0
# 92814          95       164000         0
# 91866          94       226987         1
# 92816          94       198371         0
#
#                                               artists  \
# 93802    ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                              ['Olivia Rodrigo']
# 93804                                 ['Masked Wolf']
# 92810                                  ['The Weeknd']
# 92811                                  ['Kali Uchis']
# 92813                                  ['The Weeknd']
# 93805  ['Bruno Mars', 'Anderson .Paak', 'Silk Sonic']
# 92814                                     ['TiÃ«sto']
# 91866                                    ['Doja Cat']
# 92816                                      ['Giveon']
#
#                                               id_artists release_date  \
# 93802  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   19/03/2021
# 93803                         ['1McMsnEElThX1knmY4oliG']   08/01/2021
# 93804                         ['1uU7g3DNSbsu0QjSEqZtEd']   06/01/2021
# 92810                         ['1Xyo4u8uXC1ZmMpatF05PJ']   20/03/2020
# 92811                         ['1U1el3k54VvEUzo3ybLPlM']   04/12/2020
# 92813                         ['1Xyo4u8uXC1ZmMpatF05PJ']   20/03/2020
# 93805  ['0du5cEVh5yTK9QJze8zA0C', '3jK9MiCrA42lLAdMGU...   05/03/2021
# 92814                         ['2o5jDhtHVPhrJdv3cEQ99Z']   16/09/2020
# 91866                         ['5cj0lLjcoR7YOSnhnX0Po5']   07/11/2019
# 92816                         ['4fxd5Ee7UefO4CUXgwJ7IP']   27/03/2020
#
#        danceability  energy  ...  mode  speechiness  acousticness  \
# 93802         0.677   0.696  ...     1       0.1190       0.32100
# 93803         0.585   0.436  ...     1       0.0601       0.72100
# 93804         0.778   0.695  ...     0       0.0913       0.17500
# 92810         0.680   0.826  ...     1       0.0309       0.02120
# 92811         0.653   0.524  ...     0       0.0502       0.11200
# 92813         0.514   0.730  ...     1       0.0598       0.00146
# 93805         0.586   0.616  ...     1       0.0324       0.18200
# 92814         0.798   0.620  ...     0       0.2320       0.41400
# 91866         0.749   0.463  ...     1       0.0828       0.20800
# 92816         0.449   0.465  ...     1       0.0791       0.52400
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 93802          0.000000    0.4200    0.464   90.030               4
# 93803          0.000013    0.1050    0.132  143.874               4
# 93804          0.000000    0.1500    0.472  149.996               4
# 92810          0.000012    0.5430    0.644  118.051               4
# 92811          0.000000    0.2030    0.553   83.970               4
# 92813          0.000095    0.0897    0.334  171.005               4
# 93805          0.000000    0.0927    0.719  148.088               4
# 92814          0.019200    0.1120    0.235  120.031               4
# 91866          0.037100    0.3370    0.190   90.028               4
# 92816          0.000001    0.3030    0.543   89.087               3
#
#        Unnamed: 20  release_date.1
# 93802          NaN             NaN
# 93803          NaN             NaN
# 93804          NaN             NaN
# 92810          NaN             NaN
# 92811          NaN             NaN
# 92813          NaN             NaN
# 93805          NaN             NaN
# 92814          NaN             NaN
# 91866          NaN             NaN
# 92816          NaN             NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# # Top 10 least popular songs on Platform

# %%
least = tracks.sort_values('popularity', ascending = True).head(10)
least
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                 æ‹ã¯æ°´ã®ä¸Šã§           0
# 546221                                    ç§ã®èª•ç”Ÿæ—¥           0
# 546220                  ã‚¨ãƒ«ãƒ»ãƒãƒ§ã‚¯ãƒ­ (EL CHOCLO)           0
# 546219                           æ‹ã¯ä¸æ€è­°ãªã‚‚ã®           0
# 546218       ã‚†ã†ã¹ã¯ã©ã†ã—ãŸã® (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# 546216                                 ãƒ–ãƒ«ãƒ¼ãƒžãƒ³ãƒœ           0
# 546215  Screen Director's Playhouse, Trade Winds direc...           0
# 546214  Screen Director's Playhouse, It's A Wonderful ...           0
#
#         duration_ms  explicit  \
# 546130       896575         0
# 546222       188440         0
# 546221       173467         0
# 546220       205280         0
# 546219       185733         0
# 546218       183427         0
# 546217      1767071         0
# 546216       162147         0
# 546215      1776652         0
# 546214      1767576         0
#
#                                                   artists  \
# 546130  ['Norris Goff', 'Chester Lauck', 'Carlton Bric...
# 546222                                  ['Hibari Misora']
# 546221                                  ['Hibari Misora']
# 546220                                  ['Hibari Misora']
# 546219                                  ['Hibari Misora']
# 546218                                  ['Hibari Misora']
# 546217  ['Wilms Herbert', 'June Allyson', 'Joseph Kear...
# 546216                                  ['Hibari Misora']
# 546215  ['Wally Maher', 'Tay Garnett', 'Lurene Tuttle'...
# 546214  ['Joseph Granby', 'Jimmy Stewart', 'Irene Tedr...
#
#                                                id_artists release_date  \
# 546130  ['3WCwCPDMpGzrt0Qz6quumy', '7vk8UqABg0Sga78GI3...   20/02/1935
# 546222                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546221                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546220                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546219                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546218                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546217  ['2rbm8QWvmnVwxFo84EVM1h', '4yW5adMgyIfHFzaL9i...   10/04/1949
# 546216                         ['1m5pMY5blqJwdxJ7vqQtuN']         1949
# 546215  ['7hkhJTTI3VnUGVWUt8SJXT', '3kYeeIpRCgJz4fQYDv...   19/05/1949
# 546214  ['6GK59BC4LJzqR0OpHAX2S3', '58BzBaExrnrx898sby...   08/05/1949
#
#         danceability  energy  ...  mode  speechiness  acousticness  \
# 546130         0.595   0.262  ...     1       0.9320         0.993
# 546222         0.418   0.388  ...     1       0.0358         0.925
# 546221         0.642   0.178  ...     1       0.0501         0.993
# 546220         0.695   0.467  ...     0       0.0422         0.827
# 546219         0.389   0.388  ...     1       0.0351         0.869
# 546218         0.631   0.249  ...     1       0.0355         0.951
# 546217         0.533   0.317  ...     1       0.9180         0.682
# 546216         0.529   0.546  ...     0       0.0418         0.784
# 546215         0.599   0.321  ...     0       0.9330         0.808
# 546214         0.645   0.341  ...     1       0.8670         0.690
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 546130          0.007510    0.0991    0.320   79.849               4
# 546222          0.000014    0.1050    0.439   94.549               4
# 546221          0.000943    0.0928    0.715  119.013               4
# 546220          0.000000    0.0861    0.756  125.941               4
# 546219          0.000000    0.0924    0.372   72.800               4
# 546218          0.000000    0.0814    0.517  131.097               4
# 546217          0.000000    0.3330    0.336   76.836               4
# 546216          0.000000    0.3750    0.903  128.604               4
# 546215          0.000000    0.5570    0.379   93.025               4
# 546214          0.000000    0.1530    0.431  117.591               4
#
#         Unnamed: 20  release_date.1
# 546130          NaN             NaN
# 546222          NaN             NaN
# 546221          NaN             NaN
# 546220          NaN             NaN
# 546219          NaN             NaN
# 546218          NaN             NaN
# 546217          NaN             NaN
# 546216          NaN             NaN
# 546215          NaN             NaN
# 546214          NaN             NaN
#
# [10 rows x 22 columns]

# %% [markdown]
# # Check artist at 18th row of Music Tracks Dataset

# %%
tracks[['artists']].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 18, dtype: object

# %% [markdown]
# # Converting duration from millisecond to second on Music Tracks Dataset

# %%
tracks['duration'] = tracks['duration_ms'].apply (lambda x : round(x/1000))
tracks.drop('duration_ms', inplace = True, axis=1)
tracks.duration.head()
# Out:
# 0    127
# 1     98
# 2    182
# 3    177
# 4    163
# Name: duration, dtype: int64

# %% [markdown]
# # Considering 0.4% of the total dataset to create Regression plots

# %%
sam = tracks.sample(int(0.004 * len(tracks)))
len(sam)
# Out:
# 2346

# %% [markdown]
# # Regression plot - Correlation between Loudness and Energy

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sam, y='loudness', x='energy', color='c').set(title='Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %% [markdown]
# # Regression plot - Correlation between Popularity and Acousticness

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sam, y='popularity', x='acousticness', color='b').set(title='Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %%
tracks.head()
# Out:
#                        id                                  name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                 Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  CapÃ­tulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc    Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45         El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                   Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   22/02/1922
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   01/06/1922
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   21/03/1922
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   21/03/1922
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
#    danceability  energy  key  ...  speechiness  acousticness  \
# 0         0.645  0.4450    0  ...       0.4510         0.674
# 1         0.695  0.2630    0  ...       0.9570         0.797
# 2         0.434  0.1770    1  ...       0.0512         0.994
# 3         0.321  0.0946    7  ...       0.0504         0.995
# 4         0.402  0.1580    3  ...       0.0390         0.989
#
#    instrumentalness  liveness  valence    tempo  time_signature  Unnamed: 20  \
# 0            0.7440     0.151    0.127  104.851               3          NaN
# 1            0.0000     0.148    0.655  102.009               1          NaN
# 2            0.0218     0.212    0.457  130.418               5          NaN
# 3            0.9180     0.104    0.397  169.980               3          NaN
# 4            0.1300     0.311    0.196  103.220               4          NaN
#
#    release_date.1  duration
# 0          2018.0       127
# 1          2001.0        98
# 2          2002.0       182
# 3          2003.0       177
# 4          2001.0       163
#
# [5 rows x 22 columns]

# %%
data = pd.read_csv('billboardHot100_1950_2015.csv')

# %%
# data1 = data.loc[:,['year', 'title']]
data1 = data.loc[:,['pos', 'year', 'title', 'artist',
       'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature', 'year_bin',
       'cluster', 'Gender']]

# %%
data1
# Out:
#         pos  year                  title                artist  danceability  \
# 0     0.199  1950              Mona Lisa         Nat King Cole         0.214
# 1     0.224  1950       I Wanna Be Loved       Andrews Sisters         0.358
# 2     0.351  1950        Tennessee Waltz            Patti Page         0.424
# 3     0.231  1950     I'll Never Be Free  Tennessee Ernie Ford         0.697
# 4     0.079  1950            All My Love            Patti Page         0.631
# ...     ...   ...                    ...                   ...           ...
# 4023  0.120  2015                   Here          Alessia Cara         0.376
# 4024  0.184  2015                  Waves             Mr. Probz         0.829
# 4025  0.067  2015              She Knows                 Ne-Yo         0.701
# 4026  0.026  2015          Night Changes         One Direction         0.672
# 4027  0.189  2015  How Deep Is Your Love         Calvin Harris         0.738
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.194    1   -15.636     1       0.0325       0.90300
# 1      0.085    8   -13.664     1       0.0389       0.93900
# 2      0.163    3   -15.899     1       0.0276       0.78400
# 3      0.182    7   -12.586     1       0.0357       0.78000
# 4      0.273    8   -11.538     1       0.0408       0.80100
# ...      ...  ...       ...   ...          ...           ...
# 4023   0.810    0    -4.003     1       0.1660       0.08440
# 4024   0.510    5    -9.334     0       0.0369       0.00821
# 4025   0.571    8    -5.876     0       0.0322       0.02510
# 4026   0.520    8    -7.747     1       0.0353       0.85900
# 4027   0.868   11    -4.373     0       0.0731       0.03890
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# 0             0.000001    0.1070    0.339   86.198     207573.0
# 1             0.000000    0.1600    0.181  170.869     198027.0
# 2             0.000671    0.1160    0.294   86.335     182733.0
# 3             0.000000    0.1260    0.474   82.184     158000.0
# 4             0.000000    0.1580    0.633  123.314     190933.0
# ...                ...       ...      ...      ...          ...
# 4023          0.000000    0.0730    0.340  123.909     199453.0
# 4024          0.001400    0.0829    0.450  119.993     208133.0
# 4025          0.000000    0.5610    0.533  139.988     214726.0
# 4026          0.000000    0.1150    0.370  120.001     226600.0
# 4027          0.001710    0.3880    0.336  122.003     212640.0
#
#       time_signature year_bin       cluster  Gender
# 0                  3      50s  String Lover    male
# 1                  5      50s  String Lover   Group
# 2                  3      50s  String Lover  female
# 3                  3      50s  String Lover    male
# 4                  4      50s  String Lover  female
# ...              ...      ...           ...     ...
# 4023               4      10s        Poetic  female
# 4024               4      10s  String Lover    male
# 4025               4      10s        Poetic    male
# 4026               4      10s  String Lover   Group
# 4027               4      10s  String Lover    male
#
# [4028 rows x 20 columns]

# %%
print("1:%d 2:%d"%(len(data1),len(data)))
# Out:
# 1:4028 2:4028

# %%
nsongs = {}
for y in range(1950,2016):
    nsongs[y] = len(data1[data1.year==y])
    print("Year=%d, nsongs=%d" % (y, nsongs[y]))
# Out:
# Year=1950, nsongs=8
# Year=1951, nsongs=12
# Year=1952, nsongs=6
# Year=1953, nsongs=9
# Year=1954, nsongs=14
# Year=1955, nsongs=8
# Year=1956, nsongs=39
# Year=1957, nsongs=46
# Year=1958, nsongs=42
# Year=1959, nsongs=37
# Year=1960, nsongs=42
# Year=1961, nsongs=44
# Year=1962, nsongs=44
# Year=1963, nsongs=45
# Year=1964, nsongs=55
# Year=1965, nsongs=59
# Year=1966, nsongs=60
# Year=1967, nsongs=70
# Year=1968, nsongs=46
# Year=1969, nsongs=54
# Year=1970, nsongs=58
# Year=1971, nsongs=54
# Year=1972, nsongs=59
# Year=1973, nsongs=66
# Year=1974, nsongs=72
# Year=1975, nsongs=60
# Year=1976, nsongs=65
# Year=1977, nsongs=67
# Year=1978, nsongs=73
# Year=1979, nsongs=71
# Year=1980, nsongs=72
# Year=1981, nsongs=79
# Year=1982, nsongs=75
# Year=1983, nsongs=80
# Year=1984, nsongs=81
# Year=1985, nsongs=78
# Year=1986, nsongs=77
# Year=1987, nsongs=69
# Year=1988, nsongs=78
# Year=1989, nsongs=70
# Year=1990, nsongs=77
# Year=1991, nsongs=61
# Year=1992, nsongs=70
# Year=1993, nsongs=70
# Year=1994, nsongs=78
# Year=1995, nsongs=61
# Year=1996, nsongs=60
# Year=1997, nsongs=67
# Year=1998, nsongs=56
# Year=1999, nsongs=71
# Year=2000, nsongs=65
# Year=2001, nsongs=67
# Year=2002, nsongs=69
# Year=2003, nsongs=81
# Year=2004, nsongs=77
# Year=2005, nsongs=80
# Year=2006, nsongs=71
# Year=2007, nsongs=76
# Year=2008, nsongs=81
# Year=2009, nsongs=78
# Year=2010, nsongs=82
# Year=2011, nsongs=80
# Year=2012, nsongs=76
# Year=2013, nsongs=75
# Year=2014, nsongs=79
# Year=2015, nsongs=76

# %%
yrs = range(1950,2016)
values = [nsongs[y] for y in yrs]
plt.bar(yrs, values, align='center')
plt.xlabel("Year")
plt.ylabel("Number of songs")
# Out:
# Text(0, 0.5, 'Number of songs')

# %%
df = data1
df_g = df.groupby('year')

# %%
attr = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
       'duration_ms', 'time_signature']
y_vals = []
i = 1
plt.figure(figsize=(15,20))
for a in attr:
    y_vals = []
    for name, groups in df_g:
    #     print(name)
        y_vals.append(groups[a].mean())
    plt.subplot(7, 2, i)
    plt.plot(yrs, y_vals)
    plt.ylabel(a)
    i += 1

# %%
nsongs = {}
for y in range(1922,2012):
    nsongs[y] = len(data[data.year==y])
yrs = range(1922,2011)
values = [nsongs[y] for y in yrs]
plt.bar(yrs, values, align='center')
plt.xlabel("Year")
plt.ylabel("Number of songs")
# Out:
# Text(0, 0.5, 'Number of songs')

# %% [markdown]
# # read data

# %%
spotify_df=pd.read_csv('spotify Data.csv')

# %%
spotify_df.head()
# Out:
#                      ts                      username platform  ms_played  \
# 0  2023-01-06T14:15:42Z  31k4xbqhsw7unisqoe62lohjknma      ios     154275
# 1  2023-01-06T14:16:23Z  31k4xbqhsw7unisqoe62lohjknma      ios      39832
# 2  2023-01-06T14:19:00Z  31k4xbqhsw7unisqoe62lohjknma      ios     156680
# 3  2023-01-06T14:21:24Z  31k4xbqhsw7unisqoe62lohjknma      ios     140805
# 4  2023-01-06T14:24:29Z  31k4xbqhsw7unisqoe62lohjknma      ios     168642
#
#   conn_country ip_addr_decrypted user_agent_decrypted  \
# 0           IN     106.197.9.194              unknown
# 1           IN     106.197.9.194              unknown
# 2           IN     106.197.9.194              unknown
# 3           IN     106.197.9.194              unknown
# 4           IN     106.197.9.194              unknown
#
#   master_metadata_track_name master_metadata_album_artist_name  \
# 0                      Zehen                            Mitraz
# 1                    Mehboob                            Mitraz
# 2                  Enna Sona                            Mitraz
# 3                Teri Rahaan                            Mitraz
# 4              Lage Nahi Man                      Vismay Patel
#
#   master_metadata_album_album_name  ... episode_name episode_show_name  \
# 0                            Zehen  ...          NaN               NaN
# 1                            Zehen  ...          NaN               NaN
# 2                        Enna Sona  ...          NaN               NaN
# 3                      Teri Rahaan  ...          NaN               NaN
# 4                    Lage Nahi Man  ...          NaN               NaN
#
#   spotify_episode_uri reason_start reason_end shuffle  skipped  offline  \
# 0                 NaN     clickrow  trackdone   False    False    False
# 1                 NaN    trackdone    endplay   False     True    False
# 2                 NaN     clickrow    endplay   False     True    False
# 3                 NaN    trackdone    endplay   False     True    False
# 4                 NaN     clickrow    endplay   False     True    False
#
#    offline_timestamp  incognito_mode
# 0         1673014387           False
# 1         1673014542           False
# 2         1673014583           False
# 3         1673014741           False
# 4         1673014897           False
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (4028, 20)

# %%
spotify_df.to_csv('spotify Data.csv', index=False)

# %%
spotify_df
# Out:
#                         ts                      username platform  ms_played  \
# 0     2023-01-06T14:15:42Z  31k4xbqhsw7unisqoe62lohjknma      ios     154275
# 1     2023-01-06T14:16:23Z  31k4xbqhsw7unisqoe62lohjknma      ios      39832
# 2     2023-01-06T14:19:00Z  31k4xbqhsw7unisqoe62lohjknma      ios     156680
# 3     2023-01-06T14:21:24Z  31k4xbqhsw7unisqoe62lohjknma      ios     140805
# 4     2023-01-06T14:24:29Z  31k4xbqhsw7unisqoe62lohjknma      ios     168642
# ...                    ...                           ...      ...        ...
# 2804  2023-09-15T16:07:16Z  31k4xbqhsw7unisqoe62lohjknma      ios     200373
# 2805  2023-09-15T16:17:49Z  31k4xbqhsw7unisqoe62lohjknma      ios     154554
# 2806  2023-09-15T16:18:46Z  31k4xbqhsw7unisqoe62lohjknma      ios       9056
# 2807  2023-09-15T16:22:18Z  31k4xbqhsw7unisqoe62lohjknma      ios     200373
# 2808  2023-09-15T16:26:44Z  31k4xbqhsw7unisqoe62lohjknma      ios     266075
#
#      conn_country ip_addr_decrypted user_agent_decrypted  \
# 0              IN     106.197.9.194              unknown
# 1              IN     106.197.9.194              unknown
# 2              IN     106.197.9.194              unknown
# 3              IN     106.197.9.194              unknown
# 4              IN     106.197.9.194              unknown
# ...           ...               ...                  ...
# 2804           IN   223.238.119.117              unknown
# 2805           IN   223.238.113.180              unknown
# 2806           IN   223.238.113.180              unknown
# 2807           IN   223.238.113.180              unknown
# 2808           IN   223.238.113.180              unknown
#
#                              master_metadata_track_name  \
# 0                                                 Zehen
# 1                                               Mehboob
# 2                                             Enna Sona
# 3                                           Teri Rahaan
# 4                                         Lage Nahi Man
# ...                                                 ...
# 2804                             Chaleya (From "Jawan")
# 2805                                           With You
# 2806                                    52 Gaj Ka Daman
# 2807                             Chaleya (From "Jawan")
# 2808  Phir Aur Kya Chahiye (From "Zara Hatke Zara Ba...
#
#      master_metadata_album_artist_name  \
# 0                               Mitraz
# 1                               Mitraz
# 2                               Mitraz
# 3                               Mitraz
# 4                         Vismay Patel
# ...                                ...
# 2804               Anirudh Ravichander
# 2805                        AP Dhillon
# 2806                     Renuka Panwar
# 2807               Anirudh Ravichander
# 2808                      Sachin-Jigar
#
#                        master_metadata_album_album_name  ... episode_name  \
# 0                                                 Zehen  ...          NaN
# 1                                                 Zehen  ...          NaN
# 2                                             Enna Sona  ...          NaN
# 3                                           Teri Rahaan  ...          NaN
# 4                                         Lage Nahi Man  ...          NaN
# ...                                                 ...  ...          ...
# 2804                             Chaleya (From "Jawan")  ...          NaN
# 2805                                           With You  ...          NaN
# 2806                                    52 Gaj Ka Daman  ...          NaN
# 2807                             Chaleya (From "Jawan")  ...          NaN
# 2808  Phir Aur Kya Chahiye (From "Zara Hatke Zara Ba...  ...          NaN
#
#      episode_show_name spotify_episode_uri reason_start reason_end shuffle  \
# 0                  NaN                 NaN     clickrow  trackdone   False
# 1                  NaN                 NaN    trackdone    endplay   False
# 2                  NaN                 NaN     clickrow    endplay   False
# 3                  NaN                 NaN    trackdone    endplay   False
# 4                  NaN                 NaN     clickrow    endplay   False
# ...                ...                 ...          ...        ...     ...
# 2804               NaN                 NaN     clickrow  trackdone    True
# 2805               NaN                 NaN    trackdone  trackdone    True
# 2806               NaN                 NaN    trackdone    endplay    True
# 2807               NaN                 NaN     clickrow  trackdone    True
# 2808               NaN                 NaN    trackdone  trackdone    True
#
#       skipped  offline  offline_timestamp  incognito_mode
# 0       False    False         1673014387           False
# 1        True    False         1673014542           False
# 2        True    False         1673014583           False
# 3        True    False         1673014741           False
# 4        True    False         1673014897           False
# ...       ...      ...                ...             ...
# 2804    False    False         1694793837           False
# 2805    False    False         1694794037           False
# 2806     True    False         1694794700           False
# 2807    False    False         1694794727           False
# 2808    False    False         1694794938           False
#
# [2809 rows x 21 columns]

# %% [markdown]
# # Data preparation and cleaning

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2809 entries, 0 to 2808
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ts                                 2809 non-null   object
#  1   username                           2809 non-null   object
#  2   platform                           2809 non-null   object
#  3   ms_played                          2809 non-null   int64
#  4   conn_country                       2809 non-null   object
#  5   ip_addr_decrypted                  2809 non-null   object
#  6   user_agent_decrypted               2809 non-null   object
#  7   master_metadata_track_name         2808 non-null   object
#  8   master_metadata_album_artist_name  2808 non-null   object
#  9   master_metadata_album_album_name   2808 non-null   object
#  10  spotify_track_uri                  2808 non-null   object
#  11  episode_name                       1 non-null      object
#  12  episode_show_name                  1 non-null      object
#  13  spotify_episode_uri                1 non-null      object
#  14  reason_start                       2809 non-null   object
#  15  reason_end                         2809 non-null   object
#  16  shuffle                            2809 non-null   bool
#  17  skipped                            2809 non-null   bool
#  18  offline                            2809 non-null   bool
#  19  offline_timestamp                  2809 non-null   int64
#  20  incognito_mode                     2809 non-null   bool
# dtypes: bool(4), int64(2), object(15)
# memory usage: 384.2+ KB

# %%
spotify_df.nunique()
# Out:
# ts                                   2783
# username                                1
# platform                                1
# ms_played                            1811
# conn_country                            1
# ip_addr_decrypted                     297
# user_agent_decrypted                    1
# master_metadata_track_name            986
# master_metadata_album_artist_name     498
# master_metadata_album_album_name      911
# spotify_track_uri                    1027
# episode_name                            1
# episode_show_name                       1
# spotify_episode_uri                     1
# reason_start                            9
# reason_end                              7
# shuffle                                 2
# skipped                                 2
# offline                                 1
# offline_timestamp                    2784
# incognito_mode                          1
# dtype: int64

# %%
spotify_stream_df = spotify_df[['ts', 'ms_played', 'master_metadata_track_name', 'master_metadata_album_artist_name']].copy()
spotify_stream_df.head()
# Out:
#                      ts  ms_played master_metadata_track_name  \
# 0  2023-01-06T14:15:42Z     154275                      Zehen
# 1  2023-01-06T14:16:23Z      39832                    Mehboob
# 2  2023-01-06T14:19:00Z     156680                  Enna Sona
# 3  2023-01-06T14:21:24Z     140805                Teri Rahaan
# 4  2023-01-06T14:24:29Z     168642              Lage Nahi Man
#
#   master_metadata_album_artist_name
# 0                            Mitraz
# 1                            Mitraz
# 2                            Mitraz
# 3                            Mitraz
# 4                      Vismay Patel

# %%
spotify_stream_df['ts'] = pd.to_datetime(spotify_stream_df['ts'])
spotify_stream_df['ts'] = spotify_stream_df['ts'].dt.strftime('%Y-%m-%d %H:%M')

spotify_stream_df.head()
# Out:
#                  ts  ms_played master_metadata_track_name  \
# 0  2023-01-06 14:15     154275                      Zehen
# 1  2023-01-06 14:16      39832                    Mehboob
# 2  2023-01-06 14:19     156680                  Enna Sona
# 3  2023-01-06 14:21     140805                Teri Rahaan
# 4  2023-01-06 14:24     168642              Lage Nahi Man
#
#   master_metadata_album_artist_name
# 0                            Mitraz
# 1                            Mitraz
# 2                            Mitraz
# 3                            Mitraz
# 4                      Vismay Patel

# %%
len(spotify_stream_df["master_metadata_album_artist_name"].unique()) # Length of unique artist
# Out:
# 499

# %%
len(spotify_stream_df["master_metadata_track_name"].unique()) # Length of unique tracks
# Out:
# 987

# %% [markdown]
# # Data formatting

# %%
spotify_stream_df["Play-Time"]= pd.to_datetime(spotify_stream_df["ts"]) # To create a additional column

# %%
spotify_stream_df['year'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).year
spotify_stream_df['month'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).month
spotify_stream_df['day'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).day
spotify_stream_df['weekday'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).weekday
spotify_stream_df['time'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).time
spotify_stream_df['hours'] = pd.DatetimeIndex(spotify_stream_df["Play-Time"]).hour
spotify_stream_df['day-name'] = spotify_stream_df["Play-Time"].apply(lambda x: x.day_name())
spotify_stream_df['Count'] = 1

# %%
spotify_stream_df["Time-Played (hh-mm-ss)"] = pd.to_timedelta(spotify_stream_df["ms_played"], unit='ms')

# %%
def hours(td):
    # To get the hour information
    return td.seconds/3600

def minutes(td):
    # To get the minutes information
    return (td.seconds/60)%60

spotify_stream_df["Listening Time(Hours)"] = spotify_stream_df["Time-Played (hh-mm-ss)"].apply(hours).round(3)
spotify_stream_df["Listening Time(Minutes)"] = spotify_stream_df["Time-Played (hh-mm-ss)"].apply(minutes).round(3)

# %%
spotify_stream_df.head() # To check the newly formed dataset with additional columns
# Out:
#                  ts  ms_played master_metadata_track_name  \
# 0  2023-01-06 14:15     154275                      Zehen
# 1  2023-01-06 14:16      39832                    Mehboob
# 2  2023-01-06 14:19     156680                  Enna Sona
# 3  2023-01-06 14:21     140805                Teri Rahaan
# 4  2023-01-06 14:24     168642              Lage Nahi Man
#
#   master_metadata_album_artist_name           Play-Time  year  month  day  \
# 0                            Mitraz 2023-01-06 14:15:00  2023      1    6
# 1                            Mitraz 2023-01-06 14:16:00  2023      1    6
# 2                            Mitraz 2023-01-06 14:19:00  2023      1    6
# 3                            Mitraz 2023-01-06 14:21:00  2023      1    6
# 4                      Vismay Patel 2023-01-06 14:24:00  2023      1    6
#
#    weekday      time  hours day-name  Count Time-Played (hh-mm-ss)  \
# 0        4  14:15:00     14   Friday      1 0 days 00:02:34.275000
# 1        4  14:16:00     14   Friday      1 0 days 00:00:39.832000
# 2        4  14:19:00     14   Friday      1 0 days 00:02:36.680000
# 3        4  14:21:00     14   Friday      1 0 days 00:02:20.805000
# 4        4  14:24:00     14   Friday      1 0 days 00:02:48.642000
#
#    Listening Time(Hours)  Listening Time(Minutes)
# 0                  0.043                    2.567
# 1                  0.011                    0.650
# 2                  0.043                    2.600
# 3                  0.039                    2.333
# 4                  0.047                    2.800

# %%
spotify_stream_df.drop(columns=["ts","Time-Played (hh-mm-ss)","ms_played"], inplace=True)

# %%
spotify_stream_df.describe() # Final check for any abnormality
# Out:
#                            Play-Time    year        month          day  \
# count                           2809  2809.0  2809.000000  2809.000000
# mean   2023-05-24 13:02:12.837308672  2023.0     5.271983    15.153791
# min              2023-01-06 14:15:00  2023.0     1.000000     1.000000
# 25%              2023-04-03 13:13:00  2023.0     4.000000     6.000000
# 50%              2023-05-27 11:26:00  2023.0     5.000000    15.000000
# 75%              2023-07-20 11:29:00  2023.0     7.000000    24.000000
# max              2023-09-15 16:26:00  2023.0     9.000000    31.000000
# std                              NaN     0.0     2.160923     9.145344
#
#            weekday        hours   Count  Listening Time(Hours)  \
# count  2809.000000  2809.000000  2809.0            2809.000000
# mean      3.250979    11.215379     1.0               0.035209
# min       0.000000     0.000000     1.0               0.000000
# 25%       1.000000     8.000000     1.0               0.005000
# 50%       4.000000    12.000000     1.0               0.037000
# 75%       5.000000    14.000000     1.0               0.058000
# max       6.000000    23.000000     1.0               0.180000
# std       2.082868     5.304029     0.0               0.028600
#
#        Listening Time(Minutes)
# count              2809.000000
# mean                  2.112138
# min                   0.000000
# 25%                   0.283000
# 50%                   2.217000
# 75%                   3.500000
# max                  10.800000
# std                   1.715374

# %% [markdown]
# # Analysis and Visualization

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
plt.style.use('seaborn-darkgrid')

matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
# Out:
# C:\Users\AMAN SINGH\AppData\Local\Temp\ipykernel_21904\1738326915.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
unique_artists = spotify_stream_df["master_metadata_album_artist_name"].nunique() # Count number of unique artist in dataset
total_artists = spotify_stream_df["master_metadata_album_artist_name"].count() # Count total artist in dataset
unique_artist_percentage = unique_artists/total_artists*100 # Get the percentage of the unique
unique_artist_percentage
# Out:
# 17.735042735042736

# %%
unique_artist_list = np.array([unique_artists, total_artists-unique_artists])
unique_artist_list_labels = [" Unique Artists", "Non Unique Artists"]

fig, ax = plt.subplots(figsize=(12,6))
ax.pie(unique_artist_list, labels= unique_artist_list_labels, autopct='%1.1f%%',explode=[0.05,0.05] ,startangle=180, shadow = True);
plt.title("Unique Artist Percentage")
plt.show()

# %% [markdown]
# # We can also check the top 10 unique artist we have.

# %%
top_10_artist_df = spotify_stream_df.groupby(["master_metadata_album_artist_name"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Listening Time(Minutes)",ascending=False)
top_10_artist_df.head(10)
# Out:
#                                    Listening Time(Hours)  \
# master_metadata_album_artist_name
# Pritam                                            10.147
# Arijit Singh                                       9.230
# Mitraz                                             2.797
# Sachin-Jigar                                       2.757
# Tanmoy Saikia                                      2.272
# Sachet Tandon                                      2.238
# Rito Riba                                          2.205
# Vismay Patel                                       2.144
# Tanishk Bagchi                                     2.130
# AP Dhillon                                         1.744
#
#                                    Listening Time(Minutes)  Count
# master_metadata_album_artist_name
# Pritam                                             609.081    213
# Arijit Singh                                       553.781    181
# Mitraz                                             167.705     90
# Sachin-Jigar                                       165.175     61
# Tanmoy Saikia                                      136.150     38
# Sachet Tandon                                      133.929     59
# Rito Riba                                          132.363     58
# Vismay Patel                                       128.726     60
# Tanishk Bagchi                                     127.268     44
# AP Dhillon                                         104.486     56

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.bar(top_10_artist_df.head(10).index,top_10_artist_df["Listening Time(Hours)"].head(10),color='green')
ax.set(title="My Top 10 Favourite Artist (based on Hours)",xlabel="Artists",ylabel="No. of Hours Songs Played");
plt.xticks(rotation=75);

# %% [markdown]
# # Top 10 Unique Artist (count) : Based on the number of count

# %%
top_10_artist_count_df = spotify_stream_df.groupby(["master_metadata_album_artist_name"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Count",ascending=False)
top_10_artist_count_df.head(10)
# Out:
#                                    Listening Time(Hours)  \
# master_metadata_album_artist_name
# Pritam                                            10.147
# Arijit Singh                                       9.230
# Mitraz                                             2.797
# Sachin-Jigar                                       2.757
# Vismay Patel                                       2.144
# Sachet Tandon                                      2.238
# Rito Riba                                          2.205
# AP Dhillon                                         1.744
# Tanishk Bagchi                                     2.130
# Nilotpal Bora                                      1.510
#
#                                    Listening Time(Minutes)  Count
# master_metadata_album_artist_name
# Pritam                                             609.081    213
# Arijit Singh                                       553.781    181
# Mitraz                                             167.705     90
# Sachin-Jigar                                       165.175     61
# Vismay Patel                                       128.726     60
# Sachet Tandon                                      133.929     59
# Rito Riba                                          132.363     58
# AP Dhillon                                         104.486     56
# Tanishk Bagchi                                     127.268     44
# Nilotpal Bora                                       91.127     39

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.bar(top_10_artist_count_df.head(10).index,top_10_artist_count_df["Count"].head(10),color='green')
ax.set(title="My Top 10 Favourite Artist (based on Counts)",xlabel="Artists",ylabel="No. of Times Songs Played");
plt.xticks(rotation=75);

# %% [markdown]
# # We can check what is the percentage of unique songs we have

# %%
unique_songs = spotify_stream_df["master_metadata_track_name"].nunique()
total_songs = spotify_stream_df["master_metadata_track_name"].count()
unique_songs_percentage = unique_songs/total_songs*100
unique_songs_percentage
# Out:
# 35.11396011396011

# %%
unique_songs_list = np.array([unique_songs, total_songs-unique_songs])
unique_songs_list_labels = [" Unique Songs", "Non Unique Songs"]

fig, ax = plt.subplots(figsize=(12,6))
ax.pie(unique_songs_list, labels= unique_songs_list_labels, autopct='%1.1f%%', explode=[0.05,0.05], startangle=180, shadow = True);
plt.title("Unique Songs Percentage");

# %% [markdown]
# # We can also check the top 10 unique songs we have

# %%
top_10_songs_time_df = spotify_stream_df.groupby(["master_metadata_track_name"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Listening Time(Minutes)",ascending=False)
top_10_songs_count_df = spotify_stream_df.groupby(["master_metadata_track_name"])[["Listening Time(Hours)","Listening Time(Minutes)","Count"]].sum().sort_values(by="Count",ascending=False)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,5))

# first graph
ax1.bar(top_10_songs_time_df.head(10).index,top_10_songs_time_df["Listening Time(Hours)"].head(10), color="green")
ax1.set(title="My Top 10 Favourite Songs (based on Hours)",xlabel="Songs",ylabel="No. of Hours Songs Played");
ax1.tick_params(labelrotation=90);
ax1.axhline(top_10_songs_time_df["Listening Time(Hours)"][:100].mean(), linestyle="--", color="r")

# second graph
ax2.bar(top_10_songs_count_df.head(10).index,top_10_songs_count_df["Count"].head(10), color="green")
ax2.set(title="My Top 10 Favourite Songs (based on Count)",xlabel="Songs",ylabel="No. of Times Songs Played");
ax2.tick_params(labelrotation=90);
ax2.axhline(top_10_songs_count_df["Count"][:100].mean(), linestyle="--", color="r");

# %% [markdown]
# # Day Wise Usage (Exploration)

# %%
import matplotlib.cm as cm

day_name_counts = spotify_stream_df["day-name"].value_counts()
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)
colors = cm.Blues(np.linspace(0.9, 0.2, len(day_name_counts)))

# Get the maximum index
max_index = day_name_counts.argmax()

# Create an explode list
explode = [0] * len(day_name_counts)
explode[max_index] = 0.1

# Plot the pie chart
ax.pie(day_name_counts, labels=day_name_counts.index, colors=colors, autopct='%1.1f%%', startangle=-90,
       textprops={'fontsize': 14}, explode=explode, shadow=True, counterclock=False)

# Set the title and axis aspect ratio
ax.set_title('Day wise % of Spotify Streaming', pad=20, fontdict={'color': 'black', 'weight': 'normal', 'size': 16})
ax.axis('equal')

plt.show()

# %% [markdown]
# # Average Usage over a day

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.set(title="Average Distribution of Streaming Over Day Hours",xlabel="Hours (in 24 hour format)", ylabel="Songs Played")
sns.histplot(spotify_stream_df["hours"], bins=24,kde=True, color="darkgreen");

# %% [markdown]
# # Average Usage In a Year

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax = sns.countplot(y=spotify_stream_df["month"], ax=ax)
ax.set(title="Average Spotify Usage over Years", xlabel="Songs Played in Counts", ylabel="Months (1-12)");

# %% [markdown]
# # How many hours did I spent on Spotify Streaming since the day I signed up for it

# %%
time_spent_hours = spotify_stream_df["Listening Time(Hours)"].sum()
time_spent_hours
# Out:
# 98.90299999999999

# %% [markdown]
# # What is the average numbers of songs I played daily

# %%
total_songs = spotify_stream_df["master_metadata_track_name"].count()

# %%
date_df = spotify_stream_df["Play-Time"]
time_difference = (date_df.iloc[2808] - date_df.iloc[0]) / np.timedelta64(1,"D")
time_difference_hours = time_difference*24
time_difference_hours
# Out:
# 6050.183333333333

# %%
total_songs = spotify_stream_df["master_metadata_track_name"].count()

# %%
time_difference
# Out:
# 252.09097222222223

# %%
average_songs_played_daily = (total_songs / time_difference).round()
average_songs_played_daily
# Out:
# 11.0

# %% [markdown]
# # My Favourite Artist playlist based on count of songs.

# %%
my_fav_artist_playlist = spotify_stream_df.groupby(["master_metadata_album_artist_name","master_metadata_track_name"])[["Count"]].count().sort_values(by="Count",ascending=False).head(100)
my_fav_artist_playlist
# Out:
#                                                                                       Count
# master_metadata_album_artist_name master_metadata_track_name
# Mitraz                            Alfaazo                                                53
# Sachin-Jigar                      Phir Aur Kya Chahiye (From "Zara Hatke Zara Bac...     46
# Rohanpreet Singh                  Gham Khushiyan                                         33
# Rovalio                           Iraaday                                                32
# Tanmoy Saikia                     Kenekoi Bujao ("From 13")                              32
# ...                                                                                     ...
# Arijit Singh                      Galtiyan                                                6
# Dikshant                          Aankhon Se Batana                                       6
# Mohit Lalwani                     Samay Samjhayega (Lofi)                                 6
# Pritam                            Tum Kya Mile (From "Rocky Aur Rani Kii Prem Kah...      6
#                                   What Jhumka ? (From "Rocky Aur Rani Kii Prem Ka...      6
#
# [100 rows x 1 columns]

# %% [markdown]
# # Usage Analysis over a week via countplot

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.countplot(x=spotify_stream_df["day-name"],ax=ax)
plt.xticks(rotation=75);
ax.set(title="Average Spotify Usage over Week",xlabel="Days of the Week",ylabel="Counts of Songs Played");

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report,ConfusionMatrixDisplay

# %%
df=pd.read_excel("Spotify_data.xlsx")
df
# Out:
#        Age  Gender spotify_usage_period  \
# 0    20-35  Female    More than 2 years
# 1    12-20    Male    More than 2 years
# 2    35-60  Others   6 months to 1 year
# 3    20-35  Female    1 year to 2 years
# 4    20-35  Female    1 year to 2 years
# ..     ...     ...                  ...
# 515  20-35  Female    More than 2 years
# 516  20-35  Female    More than 2 years
# 517  20-35  Female    More than 2 years
# 518  20-35  Female   6 months to 1 year
# 519  20-35  Female    More than 2 years
#
#                              spotify_listening_device  \
# 0                  Smart speakers or voice assistants
# 1                                  Computer or laptop
# 2                  Smart speakers or voice assistants
# 3      Smartphone, Smart speakers or voice assistants
# 4                                          Smartphone
# ..                                                ...
# 515  Smartphone, Computer or laptop, Wearable devices
# 516                    Smartphone, Computer or laptop
# 517                                        Smartphone
# 518                                        Smartphone
# 519                    Smartphone, Computer or laptop
#
#        spotify_subscription_plan premium_sub_willingness  \
# 0            Free (ad-supported)                     Yes
# 1            Free (ad-supported)                     Yes
# 2            Free (ad-supported)                     Yes
# 3            Free (ad-supported)                      No
# 4            Free (ad-supported)                      No
# ..                           ...                     ...
# 515          Free (ad-supported)                     Yes
# 516          Free (ad-supported)                     Yes
# 517          Free (ad-supported)                      No
# 518  Premium (paid subscription)                     Yes
# 519  Premium (paid subscription)                     Yes
#
#              preffered_premium_plan preferred_listening_content  \
# 0          Family Plan-Rs 179/month                     Podcast
# 1    Individual Plan- Rs 119/ month                     Podcast
# 2          Student Plan-Rs 59/month                     Podcast
# 3                               NaN                       Music
# 4                               NaN                       Music
# ..                              ...                         ...
# 515        Student Plan-Rs 59/month                       Music
# 516        Student Plan-Rs 59/month                       Music
# 517        Student Plan-Rs 59/month                       Music
# 518  Individual Plan- Rs 119/ month                       Music
# 519        Student Plan-Rs 59/month                       Music
#
#     fav_music_genre music_time_slot  \
# 0            Melody           Night
# 1               Rap       Afternoon
# 2               Pop           Night
# 3            Melody           Night
# 4            Melody           Night
# ..              ...             ...
# 515             Pop         Morning
# 516             Pop           Night
# 517             Pop           Night
# 518          Melody           Night
# 519             Pop           Night
#
#                                 music_Influencial_mood  \
# 0                                Sadness or melancholy
# 1                         Social gatherings or parties
# 2                         Relaxation and stress relief
# 3    Relaxation and stress relief, Social gathering...
# 4                         Relaxation and stress relief
# ..                                                 ...
# 515  Uplifting and motivational, Sadness or melancholy
# 516  Relaxation and stress relief, Uplifting and mo...
# 517                       Relaxation and stress relief
# 518  Relaxation and stress relief, Uplifting and mo...
# 519  Relaxation and stress relief, Sadness or melan...
#
#                                    music_lis_frequency  \
# 0                                         leisure time
# 1                                      Workout session
# 2                         Study Hours, While Traveling
# 3          Office hours, Workout session, leisure time
# 4                                         leisure time
# ..                                                 ...
# 515                                    While Traveling
# 516     While Traveling, Workout session, leisure time
# 517                                       leisure time
# 518                      Workout session, leisure time
# 519  Office hours,Study Hours, While Traveling, lei...
#
#               music_expl_method  music_recc_rating     pod_lis_frequency  \
# 0                     Playlists                  3                 Daily
# 1                     Playlists                  2  Several times a week
# 2                     Playlists                  4           Once a week
# 3    recommendations, Playlists                  4                 Never
# 4    recommendations, Playlists                  4                Rarely
# ..                          ...                ...                   ...
# 515             recommendations                  5                Rarely
# 516                      Others                  2                Rarely
# 517             recommendations                  3                 Never
# 518     recommendations, Others                  2  Several times a week
# 519            Playlists, Radio                  3                 Never
#
#             fav_pod_genre preffered_pod_format     pod_host_preference  \
# 0                  Comedy            Interview                    Both
# 1                  Comedy            Interview                    Both
# 2                  Sports            Interview                     NaN
# 3                     NaN                  NaN                     NaN
# 4    Lifestyle and Health        Story telling  Well known individuals
# ..                    ...                  ...                     ...
# 515  Lifestyle and Health       Conversational                    Both
# 516                Comedy        Story telling                    Both
# 517                   NaN        Story telling                    Both
# 518                Comedy       Conversational                    Both
# 519                   NaN                  NaN                     NaN
#
#     preffered_pod_duration pod_variety_satisfaction
# 0                     Both                       Ok
# 1                      NaN                Satisfied
# 2                     Both                Satisfied
# 3                      NaN                       Ok
# 4                     Both                       Ok
# ..                     ...                      ...
# 515                Shorter                       Ok
# 516                Shorter                       Ok
# 517                Shorter                       Ok
# 518                 Longer                Satisfied
# 519                    NaN                       Ok
#
# [520 rows x 20 columns]

# %%
df1=df.copy()

# %%
df.dtypes
# Out:
# Age                            object
# Gender                         object
# spotify_usage_period           object
# spotify_listening_device       object
# spotify_subscription_plan      object
# premium_sub_willingness        object
# preffered_premium_plan         object
# preferred_listening_content    object
# fav_music_genre                object
# music_time_slot                object
# music_Influencial_mood         object
# music_lis_frequency            object
# music_expl_method              object
# music_recc_rating               int64
# pod_lis_frequency              object
# fav_pod_genre                  object
# preffered_pod_format           object
# pod_host_preference            object
# preffered_pod_duration         object
# pod_variety_satisfaction       object
# dtype: object

# %%
df.isna().sum()
# Out:
# Age                              0
# Gender                           0
# spotify_usage_period             0
# spotify_listening_device         0
# spotify_subscription_plan        0
# premium_sub_willingness          0
# preffered_premium_plan         208
# preferred_listening_content      0
# fav_music_genre                  0
# music_time_slot                  0
# music_Influencial_mood           0
# music_lis_frequency              0
# music_expl_method                0
# music_recc_rating                0
# pod_lis_frequency                0
# fav_pod_genre                  148
# preffered_pod_format           140
# pod_host_preference            141
# preffered_pod_duration         129
# pod_variety_satisfaction         0
# dtype: int64

# %%
#Age group
y=df['Age'].value_counts()
plt.figure(figsize=(5,5))
labels=['20-35','12-20','6-10','35-60','60+']
plt.pie(y,labels=labels,autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.title('Age distribution of spotify users')
plt.show()

# %%
#Gender
y=df['Gender'].value_counts()
plt.figure(figsize=(5,5))
labels=['Female','Male','Others']
plt.pie(y,labels=labels,autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.title('Gender that uses spotify more')
plt.show()

# %%
#spotify subscription plan
sns.countplot(x='spotify_subscription_plan',data=df,hue='Gender')
# Out:
# <Axes: xlabel='spotify_subscription_plan', ylabel='count'>

# %%
#willingness to take subscription
sns.countplot(x='premium_sub_willingness',data=df,hue='Age')
# Out:
# <Axes: xlabel='premium_sub_willingness', ylabel='count'>

# %%
#Premium Subscription willingness
y3=df['premium_sub_willingness'].value_counts()
labels=['No','Yes']
plt.pie(y3,labels=labels,autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.title('Premium Subscription willingness')
plt.show()

# %%
#fav genre
fig,ax=plt.subplots(figsize=(8,6))
y2=df['fav_music_genre'].value_counts().values
x2=df['fav_music_genre'].unique()
plt.barh(x2,y2,color='g')
plt.xlabel('Count')
plt.ylabel('Music genres')
plt.title('Preffered Music genres')
plt.show()

# %%
#fav lis content
y3=df['preferred_listening_content'].value_counts()
labels=['Music','Podcast']
plt.pie(y3,labels=labels,autopct='%1.1f%%')
plt.legend(loc='lower left')
plt.title('Preffered listening content')
plt.show()

# %%
#music recommendation rating
y4=df['music_recc_rating'].value_counts().values
x4=['3','4','5','2','1']
plt.barh(x4,y4,color='g')
plt.xlabel('Count of Ratings')
plt.ylabel('Recommendation Ratings')
plt.title('Rating by users')
plt.show()

# %%
le=LabelEncoder()
lst=['Age','Gender','spotify_usage_period','spotify_listening_device','spotify_subscription_plan','premium_sub_willingness','preffered_premium_plan','preferred_listening_content','fav_music_genre','music_time_slot','music_Influencial_mood','music_lis_frequency','music_expl_method','pod_lis_frequency','fav_pod_genre','preffered_pod_format','pod_host_preference','preffered_pod_duration','pod_variety_satisfaction']
for i in lst:
  df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#      Age  Gender  spotify_usage_period  spotify_listening_device  \
# 0      1       0                     3                         4
# 1      0       1                     3                         0
# 2      2       2                     1                         4
# 3      1       0                     0                        11
# 4      1       0                     0                         6
# ..   ...     ...                   ...                       ...
# 515    1       0                     3                        10
# 516    1       0                     3                         7
# 517    1       0                     3                         6
# 518    1       0                     1                         6
# 519    1       0                     3                         7
#
#      spotify_subscription_plan  premium_sub_willingness  \
# 0                            0                        1
# 1                            0                        1
# 2                            0                        1
# 3                            0                        0
# 4                            0                        0
# ..                         ...                      ...
# 515                          0                        1
# 516                          0                        1
# 517                          0                        0
# 518                          1                        1
# 519                          1                        1
#
#      preffered_premium_plan  preferred_listening_content  fav_music_genre  \
# 0                         1                            1                4
# 1                         2                            1                7
# 2                         3                            1                6
# 3                         4                            0                4
# 4                         4                            0                4
# ..                      ...                          ...              ...
# 515                       3                            0                6
# 516                       3                            0                6
# 517                       3                            0                6
# 518                       2                            0                4
# 519                       3                            0                6
#
#      music_time_slot  music_Influencial_mood  music_lis_frequency  \
# 0                  2                       8                   34
# 1                  0                      10                   32
# 2                  2                       0                   19
# 3                  2                       3                   13
# 4                  2                       0                   34
# ..               ...                     ...                  ...
# 515                1                      12                   26
# 516                2                       6                   29
# 517                2                       0                   34
# 518                2                       4                   33
# 519                2                       1                   15
#
#      music_expl_method  music_recc_rating  pod_lis_frequency  fav_pod_genre  \
# 0                    4                  3                  0              1
# 1                    4                  2                  4              1
# 2                    4                  4                  2             16
# 3                   13                  4                  1             19
# 4                   13                  4                  3             10
# ..                 ...                ...                ...            ...
# 515                 10                  5                  3             10
# 516                  0                  2                  3              1
# 517                 10                  3                  1             19
# 518                 11                  2                  4              1
# 519                  6                  3                  1             19
#
#      preffered_pod_format  pod_host_preference  preffered_pod_duration  \
# 0                       2                    0                       0
# 1                       2                    0                       3
# 2                       2                    3                       0
# 3                       4                    3                       3
# 4                       3                    1                       0
# ..                    ...                  ...                     ...
# 515                     0                    0                       2
# 516                     3                    0                       2
# 517                     3                    0                       2
# 518                     0                    0                       1
# 519                     4                    3                       3
#
#      pod_variety_satisfaction
# 0                           1
# 1                           2
# 2                           2
# 3                           1
# 4                           1
# ..                        ...
# 515                         1
# 516                         1
# 517                         1
# 518                         2
# 519                         1
#
# [520 rows x 20 columns]

# %%
fig, ax = plt.subplots(1,1, figsize = (12,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Key Findings from Exploratory Data Analysis
#
# The Age group that uses spotify more is between 20-35 followed by 12-20.
#
# A bigger part of the users comprises of Females than males in my dataset.
#
# Most of the users prefer free ad supported plan than premium plans and premium users are more of females.
#
# People between the age group 20-35 uses more of premium plans.
#
# 35.8 percentage of people are willing to take premium and also willing to continue with the premium subscription plan.
#
# Most of the people prefer to listen to music than podcast.
#
# Their favourite music genre is melody.
#
# Most of the users listens to songs using spotify recommendation and they have given a rating of 3 .

# %%
X=df1.drop(['Age','Gender','music_lis_frequency','fav_music_genre','spotify_usage_period','preffered_premium_plan','spotify_subscription_plan','premium_sub_willingness','music_recc_rating','preferred_listening_content','music_time_slot','music_expl_method','pod_lis_frequency','fav_pod_genre','preffered_pod_format','pod_host_preference','preffered_pod_duration','pod_variety_satisfaction'],axis=1)
X
# Out:
#                              spotify_listening_device  \
# 0                  Smart speakers or voice assistants
# 1                                  Computer or laptop
# 2                  Smart speakers or voice assistants
# 3      Smartphone, Smart speakers or voice assistants
# 4                                          Smartphone
# ..                                                ...
# 515  Smartphone, Computer or laptop, Wearable devices
# 516                    Smartphone, Computer or laptop
# 517                                        Smartphone
# 518                                        Smartphone
# 519                    Smartphone, Computer or laptop
#
#                                 music_Influencial_mood
# 0                                Sadness or melancholy
# 1                         Social gatherings or parties
# 2                         Relaxation and stress relief
# 3    Relaxation and stress relief, Social gathering...
# 4                         Relaxation and stress relief
# ..                                                 ...
# 515  Uplifting and motivational, Sadness or melancholy
# 516  Relaxation and stress relief, Uplifting and mo...
# 517                       Relaxation and stress relief
# 518  Relaxation and stress relief, Uplifting and mo...
# 519  Relaxation and stress relief, Sadness or melan...
#
# [520 rows x 2 columns]
